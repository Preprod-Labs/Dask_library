# %%
# META DATA - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - 

    # Developer details: 
        # Name: Harish S
        # Role: Architect
        # Code ownership rights: Harish S
    # Version:
        # Version: V 1.0 (Sept 13 )
            # Developer: Harish S
     
    # Description: The code enables to explore DASK library
    
# CODE - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - 

# Dependency: 
    # Environment:     
        #Python 3.12

# %% [markdown]
# DATA SOURCE : https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page
#
# Filenames :
# 1) fhvhv_tripdata_2024-05.parquet
# 2) fhvhv_tripdata_2024-06.parquet

# %% [markdown]
# ### Import Libraries

# %%
import dask #import dask library
import os #import os for system operations

# %%
import dask.dataframe as dd #import dataframe from dask to load high volume of data

# %%
data1=input("enter the path of first file : ")
df1 = dd.read_parquet(data1+'fhvhv_tripdata_2024-05.parquet') # read the first file

# %%
df1.head() # visualise first file
# Out:
#   hvfhs_license_num dispatching_base_num originating_base_num  \
# 0            HV0003               B03404               B03404
# 1            HV0003               B03404               B03404
# 2            HV0003               B03404               B03404
# 3            HV0003               B03404               B03404
# 4            HV0005               B03406                 <NA>
#
#      request_datetime   on_scene_datetime     pickup_datetime  \
# 0 2024-04-30 23:55:50 2024-04-30 23:59:00 2024-05-01 00:00:36
# 1 2024-05-01 00:41:32 2024-05-01 00:47:40 2024-05-01 00:49:40
# 2 2024-05-01 00:09:01 2024-05-01 00:10:51 2024-05-01 00:11:31
# 3 2024-05-01 00:25:43 2024-05-01 00:48:00 2024-05-01 00:48:30
# 4 2024-05-01 00:00:08                 NaT 2024-05-01 00:09:29
#
#      dropoff_datetime  PULocationID  DOLocationID  trip_miles  ...  sales_tax  \
# 0 2024-05-01 00:38:21           138            21      18.680  ...       4.48
# ...

# %%
len(df1) # no of rows in the first file
# Out:
# 20704538

# %%
data2=input("enter the path of second file : ")
df2=dd.read_parquet(data2+'fhvhv_tripdata_2024-06.parquet')

# %%
df2.head() # visualise second file
# Out:
#   hvfhs_license_num dispatching_base_num originating_base_num  \
# 0            HV0003               B03404               B03404
# 1            HV0003               B03404               B03404
# 2            HV0003               B03404               B03404
# 3            HV0003               B03404               B03404
# 4            HV0003               B03404               B03404
#
#      request_datetime   on_scene_datetime     pickup_datetime  \
# 0 2024-06-01 00:09:50 2024-06-01 00:10:33 2024-06-01 00:13:29
# 1 2024-06-01 00:25:49 2024-06-01 00:28:05 2024-06-01 00:28:35
# 2 2024-06-01 00:36:42 2024-06-01 00:42:49 2024-06-01 00:42:55
# 3 2024-06-01 00:25:11 2024-06-01 00:28:40 2024-06-01 00:32:16
# 4 2024-06-01 00:08:38 2024-06-01 00:17:19 2024-06-01 00:18:59
#
#      dropoff_datetime  PULocationID  DOLocationID  trip_miles  ...  sales_tax  \
# 0 2024-06-01 00:17:29           144           211        0.58  ...       2.78
# ...

# %%
len(df2) # no of rows in dataframe 2
# Out:
# 20123226
